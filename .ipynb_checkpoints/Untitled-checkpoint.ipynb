# %%
import pandas as pd

df_gapminder_raw = pd.read_csv('archive/gapminder - gapminder.csv')
df_lifeExp_GDPperCap_2007 = df_gapminder_raw[['country', 'population','continent', 'life_exp', 'gdp_cap']]

# %%
print(df_lifeExp_GDPperCap_2007[:10])
# Out:
#        country  population continent  life_exp       gdp_cap
# 0  Afghanistan    31889923      Asia    43.828    974.580338
# 1      Albania     3600523    Europe    76.423   5937.029526
# 2      Algeria    33333216    Africa    72.301   6223.367465
# 3       Angola    12420476    Africa    42.731   4797.231267
# 4    Argentina    40301927  Americas    75.320  12779.379640
# 5    Australia    20434176   Oceania    81.235  34435.367440
# 6      Austria     8199783    Europe    79.829  36126.492700
# 7      Bahrain      708573      Asia    75.635  29796.048340
# 8   Bangladesh   150448339      Asia    64.062   1391.253792
# 9      Belgium    10392226    Europe    79.441  33692.605080

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.scatter(
    df_lifeExp_GDPperCap_2007['gdp_cap'], df_lifeExp_GDPperCap_2007['life_exp'],
    s= df_lifeExp_GDPperCap_2007['population'] / 1e6,
    c= df_lifeExp_GDPperCap_2007['continent'].map({
        'Asia':'yellow',
        'Europe':'green',
        'Americas':'blue',
        'Africa':'red',
        'Oceania':'purple'
    }),alpha = 0.8
)

plt.xscale('log')
plt.xlabel('GDP per Capita (PPP$, log scale)')
plt.ylabel('Life Expectancy (years)')
plt.title('World Development in 2007 (Gapminder)')
plt.xticks([1000,10000,100000], ['1k','10k','100k'])

plt.text(4959.114854, 72.961, 'China', fontsize=9, ha='center', va='center')
plt.text(2452.210407, 64.698, 'India', fontsize=9, ha='center', va='center')
plt.text(42951.65309, 78.242, 'USA', fontsize=9, ha='center', va='center',c='white')

plt.grid(True, which='both', linestyle='--', linewidth=0.5)

plt.savefig('output/Gapminder_2007_World_Development_bubble_chart')
plt.show()

# %%
# Out:
#        country continent       gdp_cap
# 0  Afghanistan      Asia    974.580338
# 1      Albania    Europe   5937.029526
# 2      Algeria    Africa   6223.367465
# 3       Angola    Africa   4797.231267
# 4    Argentina  Americas  12779.379640
# 5    Australia   Oceania  34435.367440
# 6      Austria    Europe  36126.492700
# 7      Bahrain      Asia  29796.048340
# 8   Bangladesh      Asia   1391.253792
# 9      Belgium    Europe  33692.605080
